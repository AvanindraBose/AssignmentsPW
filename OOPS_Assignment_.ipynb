# %% [markdown]
# <a href="https://colab.research.google.com/github/AvanindraBose/AssignmentsPW/blob/main/OOPS_Assignment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question1
# Five Key Concepts of Object-Oriented Programming (OOP):
# Encapsulation: Bundling data (attributes) and methods that operate on the data into a single unit (class), with controlled access.
# Abstraction: Hiding complex implementation details and exposing only the essential features.
# Inheritance: Enabling a class to inherit properties and methods from another class.
# Polymorphism: Allowing different classes to define methods with the same name, enabling behavior suited to their context.
# Composition (or Association): Building complex objects by using objects of other classes.

# %%
# Question 2

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def display_info(self):
        return f"Car Info: {self.year} {self.make} {self.model}"

# Example Usage:
car = Car("Toyota", "Corolla", 2020)
print(car.display_info())
# Out:
# Car Info: 2020 Toyota Corolla

# %%
# Question 3

# %%
# Difference Between Instance Methods and Class Methods:
# Instance Methods:
# Operate on an instance of the class and can access instance attributes.
# Defined with self as the first parameter.
# Class Methods:
# Operate on the class rather than the instance and can access class-level data.
# Defined with @classmethod and cls as the first parameter.

# %%
# Question 4

# %%
class Calculator:
    def add(self, a, b=0, c=0):
        return a + b + c

calc = Calculator()
print(calc.add(5))
print(calc.add(5, 10))
print(calc.add(5, 10, 15))
# Out:
# 5
# 15
# 30

# %%
# Question 5

# %%
# Three Types of Access Modifiers in Python:
# Public: Accessible anywhere. (e.g., attribute)
# Protected: Prefix with _. Suggests it’s intended for internal use only but not strictly enforced.
# Private: Prefix with __. Enforces name mangling to restrict direct access. (e.g., __attribute).

# %%
#  Question 6

# %%
# Five Types of Inheritance in Python:
# Single Inheritance: Inherits from one parent class.
# Multiple Inheritance: Inherits from multiple classes.
# Multilevel Inheritance: A chain of inheritance.
# Hierarchical Inheritance: Multiple child classes inherit from one parent.
# Hybrid Inheritance: A mix of the above.

# %%
# Question 7

# %%
class A: pass
class B(A): pass
class C(B): pass

print(C.mro())  # or use help(C)
# Out:
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
#  Question 8

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# %%
# Question 9

# %%
def print_area(shape):
    print(f"The area is: {shape.area()}")

circle = Circle(5)
rectangle = Rectangle(4, 6)

print_area(circle)
print_area(rectangle)
# Out:
# The area is: 78.5
# The area is: 24

# %%
#  Question 10

# %%
class BankAccount:
    def __init__(self, account_number, balance):
        self.__account_number = account_number
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount > self.__balance:
            return "Insufficient funds"
        self.__balance -= amount

    def get_balance(self):
        return self.__balance

# %%
#  Question 11

# %%
class Number:
    def __init__(self, value):
        self.value = value

    def __str__(self):
        return f"Number: {self.value}"

    def __add__(self, other):
        return Number(self.value + other.value)

n1 = Number(10)
n2 = Number(20)
print(n1 + n2)  # Adds and prints using __str__
# Out:
# Number: 30

# %%
# Question 12

# %%
import time

def time_it(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f"Execution time: {end - start:.5f} seconds")
        return result
    return wrapper

@time_it
def slow_function():
    time.sleep(2)

slow_function()
# Out:
# Execution time: 2.00273 seconds

# %%
#  Question 13

# %%
# Occurs when a class inherits from two classes that share a common parent.
# Python uses MRO to resolve it, ensuring methods are called in the correct order.

# %%
class A: pass
class B(A): pass
class C(A): pass
class D(B, C): pass

print(D.mro())  # Resolves using C3 linearization
# Out:
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %%
#  Question 14

# %%
class Counter:
    instances = 0

    def __init__(self):
        Counter.instances += 1

    @classmethod
    def get_instance_count(cls):
        return cls.instances

# %%
# Question 15

# %%
class Counter:
    instances = 0

    def __init__(self):
        Counter.instances += 1

    @classmethod
    def get_instance_count(cls):
        return cls.instances
